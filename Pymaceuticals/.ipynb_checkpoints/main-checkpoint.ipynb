# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_df = mouse_metadata.merge(study_results,on='Mouse ID')
mouse_df.rename(columns={"Mouse ID":"Mouse_ID","Drug Regimen":"Drug_Regimen"},inplace=True)

# Display the data table for preview
pd.set_option('display.max_rows', 10)
mouse_df
# Out:
#      Mouse_ID Drug_Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Counting the number of unique mouse IDs in the dataset
mouseCount = len(pd.unique(mouse_df["Mouse_ID"]))
print(mouseCount)
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicateMouse = []
for i in range(0,1892):
    if mouse_df.iloc[i,5] == mouse_df.iloc[i+1,5]:
        duplicateMouse.append(mouse_df.iloc[i,0])

# %%
# Find the unique IDs from our search
duplicateID = list(pd.unique(duplicateMouse))

# %%
# Display data from duplicates
duplicate_df = mouse_df.query("Mouse_ID in @duplicateID")
duplicate_df
# Out:
#      Mouse_ID Drug_Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 594      b447     Ceftamin    Male           2          30          0
# 752      d133    Zoniferol    Male           5          30          0
# 851      f932     Ketapril    Male          15          29          0
# 908      g989     Propriva  Female          21          26          0
# 909      g989     Propriva  Female          21          26          0
# ...       ...          ...     ...         ...         ...        ...
# 1551     t573     Ceftamin  Female          15          27          0
# 1583     u153     Ceftamin  Female          11          25          0
# 1599     v199     Naftisol  Female          17          29          0
# 1743     x226     Ceftamin    Male          23          28          0
# 1753     x336     Naftisol  Female           4          29          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 594                 45.0                 0
# 752                 45.0                 0
# 851                 45.0                 0
# 908                 45.0                 0
# 909                 45.0                 0
# ...                  ...               ...
# 1551                45.0                 0
# 1583                45.0                 0
# 1599                45.0                 0
# 1743                45.0                 0
# 1753                45.0                 0
#
# [25 rows x 8 columns]

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_df = mouse_df.query("Mouse_ID not in @duplicateID")

# %%
# Checking the number of mice in the clean DataFrame.
mouseCount = len(pd.unique(mouse_df["Mouse_ID"]))
print(mouseCount)
# Out:
# 236

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen
regimen = mouse_df.groupby("Drug_Regimen")['Tumor Volume (mm3)']

pd.DataFrame(
        {
        "Mean":regimen.mean(),
        "Median":regimen.median(),
        "Variance": regimen.std() * regimen.std(),
        "Std. Dev.":regimen.std(),
        "SEM":regimen.std() / np.sqrt(regimen.count())
        }
)
# Out:
#                    Mean     Median   Variance  Std. Dev.       SEM
# Drug_Regimen
# Capomulin     40.675741  41.557809  24.947764   4.994774  0.329346
# Ceftamin      52.765682  51.910178  38.835601   6.231822  0.472433
# Infubinol     52.884795  51.820584  43.128684   6.567243  0.492236
# Ketapril      55.345698  53.739593  68.149888   8.255295  0.605308
# Naftisol      54.432995  52.544915  65.934669   8.120017  0.598616
# Placebo       54.083767  52.316010  61.051374   7.813538  0.582387
# Propriva      52.370732  50.712423  43.782776   6.616855  0.545749
# Ramicane      40.216745  40.673236  23.486704   4.846308  0.320955
# Stelasyn      54.284444  52.488221  59.303779   7.700895  0.573991
# Zoniferol     53.282012  51.826638  48.424014   6.958737  0.517239

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
regimen.agg(['mean','median',np.var,np.std,st.sem])
# Out:
#                    mean     median        var       std       sem
# Drug_Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.765682  51.910178  38.835601  6.231822  0.472433
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.345698  53.739593  68.149888  8.255295  0.605308
# Naftisol      54.432995  52.544915  65.934669  8.120017  0.598616
# Placebo       54.083767  52.316010  61.051374  7.813538  0.582387
# Propriva      52.370732  50.712423  43.782776  6.616855  0.545749
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.284444  52.488221  59.303779  7.700895  0.573991
# Zoniferol     53.282012  51.826638  48.424014  6.958737  0.517239

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

mouse_df.groupby("Drug_Regimen")['Mouse_ID'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='Drug_Regimen'>

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
plt.bar(regimen.count().keys(),regimen.count())
# Out:
# <BarContainer object of 10 artists>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

mouse_df.groupby("Sex")['Mouse_ID'].count().plot.pie()
# Out:
# <AxesSubplot:ylabel='Mouse_ID'>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(mouse_df.groupby("Sex")['Mouse_ID'].count())
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa5e80b9e50>,
#   <matplotlib.patches.Wedge at 0x7fa5e80c6370>],
#  [Text(0.03514348816569627, 1.0994384635983716, ''),
#   Text(-0.035143488165696644, -1.0994384635983716, '')])

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
maxSeries = mouse_df.groupby("Mouse_ID")["Timepoint"].max()
max_df = maxSeries.to_frame()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
finalVol_df = mouse_df.merge(max_df,on=["Mouse_ID",'Timepoint'],how='inner')
finalVol_df
# Out:
#     Mouse_ID Drug_Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 231     z314     Stelasyn  Female          21          28          5
# 232     z435     Propriva  Female          12          26         10
# 233     z581    Infubinol  Female          24          25         45
# 234     z795     Naftisol  Female          13          29         45
# 235     z969     Naftisol    Male           9          30         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# 2             28.484033                 0
# 3             28.430964                 1
# 4             29.128472                 1
# ..                  ...               ...
# 231           45.934712                 0
# 232           48.710661                 0
# 233           62.754451                 3
# 234           65.741070                 3
# 235           73.867845                 4
#
# [236 rows x 8 columns]

# %%
# Filter for the 4 drugs we are interested in
drugList = ['Capomulin','Ceftamin','Infubinol','Ramicane']
finalVol_df = finalVol_df.query("Drug_Regimen in @drugList")
finalVol_df
# Out:
#     Mouse_ID Drug_Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16         45
# 1       s185    Capomulin  Female           3          17         45
# 2       x401    Capomulin  Female          16          15         45
# 3       m601    Capomulin    Male          22          17         45
# 4       g791     Ramicane    Male          11          16         45
# ..       ...          ...     ...         ...         ...        ...
# 222     x822     Ceftamin    Male           3          29         45
# 224     y163    Infubinol  Female          17          27         45
# 228     y769     Ceftamin  Female           6          27         45
# 229     y865     Ceftamin    Male          23          26         45
# 233     z581    Infubinol  Female          24          25         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             22.050126                 1
# 1             23.343598                 1
# 2             28.484033                 0
# 3             28.430964                 1
# 4             29.128472                 1
# ..                  ...               ...
# 222           61.386660                 3
# 224           67.685569                 3
# 228           68.594745                 4
# 229           64.729837                 3
# 233           62.754451                 3
#
# [96 rows x 8 columns]

# %%
# Out:
#               Age_months  Metastatic Sites  Timepoint  Tumor Volume (mm3)  \
# Drug_Regimen
# Capomulin      14.040000          1.280000  41.000000           36.667568
# Ceftamin       12.809524          2.047619  36.428571           60.183306
# Infubinol      16.400000          1.600000  30.600000           58.178246
# Ramicane       10.840000          1.200000  40.600000           36.191390
#
#               Weight (g)
# Drug_Regimen
# Capomulin      20.120000
# Ceftamin       27.380952
# Infubinol      27.320000
# Ramicane       20.000000

# %%
# Group the last timepoint df by drug regimen and look at tumor volume
drugTumorGroup_df = finalVol_df.groupby("Drug_Regimen")['Tumor Volume (mm3)']

# aggregate the tumor volume data by count, min, mean, median, max, and iqr
iqr = drugTumorGroup_df.agg(["count",'mean','median',st.iqr])

# %%
# Identify the quartiles for each drug
quartiles = []
for i in range(0,4):
    quartiles.append(st.mstats.mquantiles(list(drugTumorGroup_df)[i][1].values))
quartile_df = pd.DataFrame(quartiles,columns=['Q1','median','Q3'],index = drugList)
quartile_df

# %%
# Merge the quartile dataframe with the drug_regimen dataframe
box_data = iqr.merge(quartile_df,on='median',left_index=True)
box_data

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
bp = finalVol_df[["Drug_Regimen","Tumor Volume (mm3)"]].groupby("Drug_Regimen").boxplot(subplots=False,rot=90)
plt.xticks([1,2,3,4])
plt.xlabel(drugList)
# Out:
# Text(0.5, 0, "['Capomulin', 'Ceftamin', 'Infubinol', 'Ramicane']")

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
